# %% [markdown]
# # Risk List Analysis

# %% [markdown]
# #### Import Required Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import sys
#Add the scripts directory path(absolute path).
sys.path.append('D://ACAPS//ACAPS//src//task-1.1-dataCollection//scripts//')

# Import the API Data Fetching Script
import acaps_dataset as ac # type: ignore

# %%
# Change the username and password according to your credentials.
# The list of all endpoints can be found at : https://api.acaps.org/api/v1/

df = ac.fetch_acaps_data(username='<username>',password='<password>', endpoint='<endpoint>')

# %%
df.head()
# Out:
#   risk_id                                            country  \
# 0   R0001                                            [Syria]
# 1   R0009  [Iran, United States, Yemen, Iraq, Syria, Afgh...
# 2   R0011                           [Bosnia and Herzegovina]
# 3   R0013                                            [Libya]
# 4   R0028                                            [Syria]
#
#                              iso3  \
# 0                           [SYR]
# 1  [IRN, USA, YEM, IRQ, SYR, AFG]
# 2                           [BIH]
# 3                           [LBY]
# 4                           [SYR]
#
#                                           risk_title  \
# 0  A full-scale offensive on northwestern Syria l...
# 1  Heightened tensions between Iran and the US an...
# 2  The arrival of 50,000 migrants, refugees, and ...
# 3  Increasing violence and consequent displacemen...
# 4  The closure of the al Yaorubia crossing worsen...
#
#                   crisis_id geographic_level  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 211 entries, 0 to 210
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   risk_id                211 non-null    object
#  1   country                211 non-null    object
#  2   iso3                   211 non-null    object
#  3   risk_title             211 non-null    object
#  4   crisis_id              178 non-null    object
#  5   geographic_level       208 non-null    object
#  6   risk_type              208 non-null    object
#  7   date_entered           211 non-null    object
#  8   last_risk_update       211 non-null    object
#  9   published              49 non-null     object
#  10  publication_link       40 non-null     object
#  11  rationale              211 non-null    object
#  12  trigger                210 non-null    object
#  13  exposure               202 non-null    object
# ...

# %%
# Features useful for Analysis and Pattern Learning: country, risk_title, geographic_level, risk_type,  rationale, trigger, exposure, intensity, vulnerability, impact, probability, status, date_entered, publication_link.

# Target:- risk_level

df.isnull().sum()
# Out:
# risk_id                    0
# country                    0
# iso3                       0
# risk_title                 0
# crisis_id                 33
# geographic_level           3
# risk_type                  3
# date_entered               0
# last_risk_update           0
# published                162
# publication_link         171
# rationale                  0
# trigger                    1
# exposure                   9
# intensity                 18
# vulnerability             14
# impact                     8
# probability                5
# risk_level                 5
# status                     1
# _internal_filter_date      0
# dtype: int64
